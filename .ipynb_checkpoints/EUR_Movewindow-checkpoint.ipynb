# %%
import pandas as pd 
import numpy as np 
import itertools

# %%
# 匯入EURUSD的數據資料
df = pd.read_csv('./Pre_data/conbine_data/EURUSD105110_05.csv', index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-533bfdcb3a03> in <module>
#       1 # 匯入EURUSD的數據資料
# ----> 2 df = pd.read_csv('./Pre_data/conbine_data/EURUSD105110_05.csv', index_col=0)
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: './Pre_data/conbine_data/EURUSD105110_05.csv'

# %%
#資料框樣子
df
# Out:
#               date                                      word2vec_body  \
# 0       2016-01-01  unemployment continues to fall inflation is in...
# 1       2016-01-01   was a year of tremendous political and econom...
# 2       2016-01-01  riverside co is ringing in the new year with i...
# 3       2016-01-01  distrust in banking system hinders capital con...
# 4       2016-01-01  in the years since a peace treaty was signed i...
# ...            ...                                                ...
# 106491  2021-05-31  grimbergen belgiumthe boss of beer giant carls...
# 106492  2021-05-31  as pro kapital grupp has not yet published aud...
# 106493  2021-05-31  it is been a big week for genocide apologies o...
# 106494  2021-05-31  water wars are no longer from apocalyptic imag...
# 106495  2021-05-31  similarly based on the pea assumptions and res...
#
#                                                tfidf_body  \
# 0       unemployment continue fall inflation check int...
# 1       year tremendous political economic volatility ...
# 2       riverside co ring new year late acquisition re...
# 3       distrust banking system hinders capital contro...
# 4       year since peace treaty sign belfast end three...
# ...                                                   ...
# 106491  grimbergen belgiumthe bos beer giant carlsberg...
# 106492  pro kapital grupp yet publish audited annual r...
# 106493  big week genocide apology friday german foreig...
# 106494  water war longer apocalyptic imagery something...
# 106495  similarly base pea assumption result eliminate...
#
#                         source_title EUR/USD(open,bid) EUR/USD(close,bid)  \
# 0                             Forbes               NAN                NAN
# 1                             Forbes               NAN                NAN
# 2            The Wall Street Journal               NAN                NAN
# 3                 Bloomberg Business               NAN                NAN
# 4       International Business Times               NAN                NAN
# ...                              ...               ...                ...
# 106491       The Wall Street Journal           1.21988            1.22231
# 106492                 Yahoo Finance           1.21988            1.22231
# 106493       The Wall Street Journal           1.21988            1.22231
# 106494                        Forbes           1.21988            1.22231
# 106495                 Yahoo Finance           1.21988            1.22231
#
#                 growth value         growth rate  result
# 0                        NAN                 NAN     0.0
# 1                        NAN                 NAN     0.0
# 2                        NAN                 NAN     0.0
# 3                        NAN                 NAN     0.0
# 4                        NAN                 NAN     0.0
# ...                      ...                 ...     ...
# 106491  0.003220000000000001  0.2641314423053261     1.0
# 106492  0.003220000000000001  0.2641314423053261     1.0
# 106493  0.003220000000000001  0.2641314423053261     1.0
# 106494  0.003220000000000001  0.2641314423053261     1.0
# 106495  0.003220000000000001  0.2641314423053261     1.0
#
# [106496 rows x 9 columns]

# %% [markdown]
# #### 儲存滑動視窗資料

# %%
import time

staryear = 105
endyear = 108
allmonth = (endyear-staryear+1)*12   #所有的月份資料的總數 -> 60
winsize = 12    #滑動月份大小 (訓練加測試3:1) 訓練75% : 測試25%

training_score = [] #用來儲存訓練結果
testing_score = [] #用來儲存測試結果

#滑動視窗設立變數
sy = 16 #起始年
ey = 17 #結束年
ty = 16 #訓練年
sm0 = 0 #起始月十位數
sm1 = 1 #起始月個位數
em0 = 0 #結束月十位數
em1 = 1 #結束月個位數
tm0 = 1 #訓練月十位數
tm1 = 2 #訓練月個位數

#滑動視窗開始
for z in range(allmonth-winsize):
    
    start = time.time()
    
    #條件判斷(這判斷之累QQQQ)
    if sm1 >= 10:
        if sm0 == 0:
            sm0 = 1
            if sm1 == 10:
                sm1 = 0
            elif sm1 == 11:
                sm1 = 1
            elif sm1 == 12:
                sm1 = 2
            elif sm1 == 13:
                sm1 = 3
        if sm0 == 1:
            if sm1 >= 3:
                sm0 = 0
                sm1 = 1
                sy += 1
                
    if em1 >= 10:
        if em0 == 0:
            em0 = 1
            if em1 == 10:
                em1 = 0
            elif em1 == 11:
                em1 = 1
            elif em1 == 12:
                em1 = 2
            elif em1 == 13:
                em1 = 3
        if em0 == 1:
            if em1 >= 3:
                em0 = 0
                em1 = 1
                ey += 1
                
    if tm1 >= 10:
        if tm0 == 0:
            tm0 = 1
            if tm1 == 10:
                tm1 = 0
            elif tm1 == 11:
                tm1 = 1
            elif tm1 == 12:
                tm1 = 2
            elif tm1 == 13:
                tm1 = 3
        if tm0 == 1:
            if tm1 >= 3:
                tm0 = 0
                tm1 = 1
                ty += 1
        
    #滑動視窗遮罩    
    start = '20%d-%d%d-01' %(sy, sm0, sm1)
    end = '20%d-%d%d-01' %(ey, em0, em1)
    test = '20%d-%d%d-01' %(ty, tm0, tm1)
    
    mask1 = df['date'] >= start
    mask2 = df['date'] < end
    
    #取出滑動視窗範圍資料
    win_df = df[(mask1 & mask2)]
    win_df = win_df.reset_index(drop=True)
    
    #每個滑動視窗各自儲存
    win_df.to_csv("./Pre_data/move_window/EUR_12/"+str(z)+".csv",index = 0)
    
    #條件判斷
    if sm0 == 1:
        sm1 = 10 * sm0 + sm1
        sm0 = 0
    if em0 == 1:
        em1 = 10 * em0 + em1
        em0 = 0
    if tm0 == 1:
        tm1 = 10 * tm0 + tm1
        tm0 = 0
    
    #視窗滑動
    em1 += 1
    sm1 += 1
    tm1 += 1
    print("滑動視窗"+str(z)+"大小:{}".format(win_df.shape))
    print('=============================')
# Out:
# 滑動視窗0大小:(20901, 9)
# =============================
# 滑動視窗1大小:(20714, 9)
# =============================
# 滑動視窗2大小:(20236, 9)
# =============================
# 滑動視窗3大小:(19708, 9)
# =============================
# 滑動視窗4大小:(19102, 9)
# =============================
# 滑動視窗5大小:(18727, 9)
# =============================
# 滑動視窗6大小:(17195, 9)
# =============================
# 滑動視窗7大小:(16194, 9)
# =============================
# 滑動視窗8大小:(15662, 9)
# =============================
# 滑動視窗9大小:(15312, 9)
# =============================
# 滑動視窗10大小:(14966, 9)
# =============================
# 滑動視窗11大小:(14441, 9)
# =============================
# 滑動視窗12大小:(13584, 9)
# =============================
# 滑動視窗13大小:(13875, 9)
# =============================
# 滑動視窗14大小:(14323, 9)
# =============================
# 滑動視窗15大小:(15008, 9)
# =============================
# 滑動視窗16大小:(15591, 9)
# =============================
# 滑動視窗17大小:(16553, 9)
# =============================
# 滑動視窗18大小:(17320, 9)
# =============================
# 滑動視窗19大小:(18026, 9)
# =============================
# 滑動視窗20大小:(18957, 9)
# =============================
# 滑動視窗21大小:(19358, 9)
# =============================
# 滑動視窗22大小:(20045, 9)
# =============================
# 滑動視窗23大小:(21113, 9)
# =============================
# 滑動視窗24大小:(21732, 9)
# =============================
# 滑動視窗25大小:(21780, 9)
# =============================
# 滑動視窗26大小:(21419, 9)
# =============================
# 滑動視窗27大小:(20824, 9)
# =============================
# 滑動視窗28大小:(20646, 9)
# =============================
# 滑動視窗29大小:(19879, 9)
# =============================
# 滑動視窗30大小:(19292, 9)
# =============================
# 滑動視窗31大小:(19260, 9)
# =============================
# 滑動視窗32大小:(18782, 9)
# =============================
# 滑動視窗33大小:(20140, 9)
# =============================
# 滑動視窗34大小:(21123, 9)
# =============================
# 滑動視窗35大小:(21922, 9)
# =============================
